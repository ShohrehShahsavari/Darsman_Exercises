# %% [markdown]
# # Introduction

# %% [markdown]
# ## 1. Import libraries

# %%
pip install missingno
# Out:
# Collecting missingnoNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for missingno from https://files.pythonhosted.org/packages/87/22/cd5cf999af21c2f97486622c551ac3d07361ced8125121e907f588ff5f24/missingno-0.5.2-py3-none-any.whl.metadata
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from missingno) (1.24.4)
# Requirement already satisfied: matplotlib in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from missingno) (3.7.2)
# Requirement already satisfied: scipy in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from missingno) (1.11.1)
# Requirement already satisfied: seaborn in c:\users\ebsor\anaconda3\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from matplotlib->missingno) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ebsor\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from matplotlib->missingno) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ebsor\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from matplotlib->missingno) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\ebsor\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ebsor\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from matplotlib->missingno) (6.0.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from seaborn->missingno) (2.0.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->missingno) (3.16.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ebsor\appdata\roaming\python\python39\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ebsor\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno

# %% [markdown]
# ## 2. Import Dataset

# %%
df=pd.read_csv('E:/Python Projects/shohreh/Shohreh_GitHub_Repository/Darsman_Exercises/term 5/3 - Air pollution/Air_pollution_ dataset.csv', delimiter=';')
df.head(2)
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
#
#        AH  Unnamed: 15  Unnamed: 16
# 0  0,7578          NaN          NaN
# 1  0,7255          NaN          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# dtypes: float64(10), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# ## 3. Air Pollution Dataset Overview
#
# ### General Information
# - **File Name**: `Air_pollution_dataset.csv`
# - **File Format**: CSV (Comma-Separated Values)
# - **Delimiter**: Semicolon (`;`)
# - **Number of Row470: 9357
# - **Number of Colum7s**#: 16
#
# ## Columns Description
# 1. **Date**: The date of the recorded data (format: `DD/MM/YYYY`).
# 2. **Time**: The time of the recorded data (format: `HH.MM.SS`).
# 3. **CO(GT)**: Carbon monoxide concentration (mg/m³).
# 4. **PT08.S1(CO)**: Tin oxide sensor response for CO (non-standardized).
# 5. **NMHC(GT)**: Non-methane hydrocarbons concentration (µg/m³).
# 6. **C6H6(GT)**: Benzene concentration (µg/m³).
# 7. **PT08.S2(NMHC)**: Titania sensor response for NMHC (non-standardized).
# 8. **NOx(GT)**: Nitrogen oxides concentration (µg/m³).
# 9. **PT08.S3(NOx)**: Tungsten oxide sensor response for NOx (non-standardized).
# 10. **NO2(GT)**: Nitrogen dioxide concentration (µg/m³).
# 11. **PT08.S4(NO2)**: Tungsten oxide sensor response for NO2 (non-standardized).
# 12. **PT08.S5(O3)**: Indium oxide sensor response for O3 (non-standardized).
# 13. **T**: Temperature (°C).
# 14. **RH**: Relative humidity (%).
# 15. **AH**: Absolute humidity (g/m³)Two
# 16. **Empty sColumn**: An emp#ty column with no data.
#
# ## Data Characteristics
# - The dataset contains hourly measurements of various air pollutants and environmental conditions.
# - Some entries contain missing or invalid data, represented by `-200`.
# - The dataset spans multiple days, with g #  | 13.3 | 47.7 | 0.7255 |              |
#
# ## Notes
# - Ensure to handle missing or invalid data (`-200`)ropriately during analysis.
# - The dataset may require putation) before use in machine learning models.

# %%
df.shape
# Out:
# (9471, 17)

# %%
df.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 113

# %% [markdown]
# ## 4. Missing values visualize

# %%
# Missing values visualize with Matrix
msno.matrix(df)
plt.title('Number of Missing values in Dataset')
plt.show()

# %% [markdown]
# ## *White line shows Null values*

# %%
# Missing values visualize with Bar
msno.bar(df, color="skyblue")
plt.title("Number of Not NULL values in Dataset")
plt.show()

# %% [markdown]
# ## *Each line shows **NotNull** values*

# %%
# Drop entirely null columns
df.dropna(axis=1, how='all', inplace=True)
df.isnull().sum()
# Out:
# Date             114
# Time             114
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %%
# Drop entirely null rows
df.dropna(axis=0, how='all', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
# dtypes: float64(8), object(7)
# memory usage: 1.1+ MB
